# %% [markdown]
# <a href="https://colab.research.google.com/github/ronva-h/technology_fundamentals/blob/main/C3%20Machine%20Learning%20I/Tech%20Fun%20C3%20S4%20FFNNs%20with%20Keras%20and%20TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Technology Explorers Course 3, Session 4: FFNNs with Keras/TensorFlow
#
# **Instructor**: Wesley Beckner
#
# **Contact**: wesleybeckner@gmail.com
#
# **Teaching Assistants**: Varsha Bang, Harsha Vardhan
#
# **Contact**: vbang@uw.edu, harshav@uw.edu
#
# <br>
#
# ---
#
# <br>
#
# In this session we will continue with our discussion on neural networks. Specifically, we will revisit the concept of learning curves, regularization and classification tasks, this time as they pertain to neural networks!
#
# _images in this notebook borrowed from [Ryan Holbrook](https://mathformachines.com/)_
#
# <br>
#
# ---
#
# <br>
#
# <a name='top'></a>
#
# # Contents
#
# * 2.0 [Preparing Environment and Importing Data](#x.0)
#   * 2.0.1 [Import Packages](#x.0.1)
#   * 2.0.2 [Load Dataset](#x.0.2)
# * 2.1 [Feature Engineering](#x.1)
# * 2.2 [Building the Model](#x.2)
#   * 2.2.1 [Layers, Nodes, and Activation Functions](#x.2.1)
# * 2.3 [Compiling the Model](#x.3)
#   * 2.3.1 [Loss, Optimizer, and Metrics](#x.3.1)
# * 2.4 [Fitting the Model](#x.4)
#   * 2.4.1 [Epoch, Batch](#x.4.1)
# * 2.5 [Evaluating the Model](#x.5)
# * 2.6 [Convolutional NNs](#x.6)
#   * 2.6.1 [Convolutional Layers](#x.6.1)
#   * 2.6.2 [Pooling Layers](#x.6.2)
#   * 2.6.3 [Flattening](#x.6.3)
#   * 2.6.4 [Dropout](#x.6.4)
#
#
#
# <br>
#
# ---

# %% [markdown]
# <a name='x.0'></a>
#
# ## 2.0 Preparing Environment and Importing Data
#
# [back to top](#top)

# %%
# !pip uninstall scikit-learn -y

# !pip install -U scikit-learn
# Out:
# Found existing installation: scikit-learn 0.24.2
# Uninstalling scikit-learn-0.24.2:
#   Successfully uninstalled scikit-learn-0.24.2
# Collecting scikit-learn
#   Using cached scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-0.24.2

# %% [markdown]
# <a name='x.0.1'></a>
#
# ### 2.0.1 Import Packages
#
# [back to top](#top)

# %%
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from copy import copy
import numpy as np
sns.set()

from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn import set_config
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
set_config(display='diagram')

# %% [markdown]
# <a name='x.0.1'></a>
#
# ### 2.0.2 Load Dataset
#
# [back to top](#top)

# %%
wine = pd.read_csv("https://raw.githubusercontent.com/wesleybeckner/"\
      "ds_for_engineers/main/data/wine_quality/winequalityN.csv")

# create X and y
X = wine.copy()
y = X.pop('quality')

# split into train/test
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train)

# the numerical values pipe
num_proc = make_pipeline(SimpleImputer(strategy='median'), StandardScaler())

# the categorical values pipe
cat_proc = make_pipeline(
    SimpleImputer(strategy='constant', fill_value='missing'),
    OneHotEncoder(handle_unknown='ignore'))

# parallelize the two pipes
preprocessor = make_column_transformer((num_proc,
                                make_column_selector(dtype_include=np.number)),
                                       (cat_proc,
                                make_column_selector(dtype_include=object)))

X_train_std = preprocessor.fit_transform(X_train) # fit_transform on train
X_test_std = preprocessor.transform(X_test) # transform test
X_val_std = preprocessor.transform(X_val)

y_train_std = np.log(y_train) # log output y
y_val_std = np.log(y_val) # log output y
y_test_std = np.log(y_test) # log output y

preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fcd5db62b10>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fcd5db62e90>)])

# %% [markdown]
# <a name='x.1'></a>
#
# ## 2.1 Evaluating the Model
#
# [back to top](#top)
#
# In the last session, we randomly chose 10 and then 30 epochs (10 rounds of the training data) to train our neural network. Now we'll garner the language to be more systematic in our approach.

# %% [markdown]
# ### 2.1.1 Learning Curves
#
# Recall learning curves from last week, where we plot model score (accuracy/mse/r2/etc.) over model complexity (trees in a forest, degrees in a polynomial, etc.):
#
# <p align=center>
# <img src="https://jakevdp.github.io/PythonDataScienceHandbook/figures/05.03-validation-curve.png" width=500px></img>
#
#
# <small>[img src](https://jakevdp.github.io/PythonDataScienceHandbook/05.03-hyperparameters-and-model-validation.html)
#
# </p>
#
# We have a similar situation with neural networks, accept here, the model complexity is defined by both the number of epochs, and the capacity of the model.

# %% [markdown]
# #### 2.1.1.1 Training Data (Epochs)
#
# A greater number of epochs allows the model to further tune itself to the training data. Remember that our model solves its weights by a solver function, most often a form of stochastic gradient descent. Because this solver is iterative, the longer we allow it run the closer it will get to finding its true weights. The caveat here is that, like we have seen before, the model is only learning the proper weights according to the training data, which we know includes noise, otherwise known as irreducible error. Our data science senses should be tingling: there's an optimum number of epochs here, and it will counter balance the trade-off between error due to bias (too few epochs) and error due to variance (too many epochs).

# %% [markdown]
# #### 2.1.1.2 Complexity (Capacity)
#
#
#
# The capacity of the model is defined by the architecture. It is the total number of trainable weights available to the solver function. The more weights, the more capacity. Capacity determines the upper limit for which our model can learn relationships between the data. Again we should recall from our session on feature engineering: the more training data we have, the more capacity we should give our model to account for that abundance of training data. This is also influenced by the actual complexity between the input and output data, X and y, who's function we are attempting to approximate with the neural network. The more complicated the relationship, the more capacity we should give to our model.
#
# Capacity can be increased either by widening our model (increasing the neurons in a layer) or deepening our model(increasing the number of layers in our model).

# %% [markdown]
# ### 2.1.2 Early Stopping
#
# [back to top](#top)
#
# Without knowing the true relationship between X and y, or the degree to which there is irreducible error in our data, we return to our familiar learning curves to pragmaticaly determine how long we should train our model, that is, how many epochs should be ran and how many neurons we should give our model.
#
# When dealing with the number of epochs, we can program this into the training session automatically with early stopping. Early stopping allows us to discontinue training the model when either the validation score stops improving, or stops improving by some margin. This allows us to both save time during training and to avoid overfitting our model.
#
# To account for underfitting (not training the model long enough) we can simply set our number of training epochs to some large number and allow early stopping to take care of the rest.
#
# In TF/Keras, we can envoke early stopping by setting a **_callback_** a callback is simply a function that is called every so often.

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# %% [markdown]
# In the above, we are saying detect when the validation loss stops improving by 0.001; check this over the past 20 epochs to avoid stopping early due to noise; and restore the best weights over that past 20 epoch period when early stopping is envoked. To envoke early stopping we would enlist it in our call to fit like so:
#
# ```
# model.fit(
#     # X, y, batch size etc, ...
#     callbacks=[early_stopping],
# )
# ```

# %% [markdown]
# ### 2.1.3 Exercise: Try Early Stopping
#
# Take your best model from the last exercise in session 1 and apply early stopping

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

model = keras.Sequential([
    ### YOUR CODE HERE ###
])

model.compile(
    optimizer='adam',
    loss='mse',
)

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

print(model.summary())

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=256,
    epochs=1000,
    verbose=1,
    callbacks=[early_stopping],
)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               7168
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,057,793
# Trainable params: 1,057,793
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# 15/15 [==============================] - 3s 11ms/step - loss: 0.4529 - val_loss: 0.1287
# Epoch 2/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0930 - val_loss: 0.0606
# Epoch 3/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0454 - val_loss: 0.0372
# Epoch 4/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0260 - val_loss: 0.0246
# Epoch 5/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0201 - val_loss: 0.0212
# Epoch 6/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0178 - val_loss: 0.0202
# Epoch 7/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0176 - val_loss: 0.0197
# Epoch 8/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0160 - val_loss: 0.0182
# Epoch 9/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0154 - val_loss: 0.0168
# Epoch 10/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0136 - val_loss: 0.0166
# Epoch 11/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0136 - val_loss: 0.0165
# Epoch 12/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0136 - val_loss: 0.0174
# Epoch 13/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0135 - val_loss: 0.0154
# Epoch 14/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0124 - val_loss: 0.0175
# Epoch 15/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0129 - val_loss: 0.0178
# Epoch 16/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0123 - val_loss: 0.0180
# Epoch 17/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0117 - val_loss: 0.0179
# Epoch 18/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0124 - val_loss: 0.0154
# Epoch 19/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0172
# Epoch 20/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0108 - val_loss: 0.0164
# Epoch 21/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0105 - val_loss: 0.0150
# Epoch 22/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0107 - val_loss: 0.0153
# Epoch 23/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0155
# Epoch 24/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0098 - val_loss: 0.0157
# Epoch 25/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0106 - val_loss: 0.0155
# Epoch 26/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0104 - val_loss: 0.0147
# Epoch 27/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0098 - val_loss: 0.0160
# Epoch 28/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0161
# Epoch 29/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0092 - val_loss: 0.0150
# Epoch 30/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0092 - val_loss: 0.0153
# Epoch 31/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0162
# Epoch 32/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0159
# Epoch 33/1000
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0096 - val_loss: 0.0173

# %%
# Show the learning curves
history_df = pd.DataFrame(history.history)
fig, ax = plt.subplots(1,1)
history_df.plot(ax=ax)
ax.set_ylim(0,.1)
# Out:
# (0.0, 0.1)

# %%
y_test_pred = np.exp(model.predict(X_test_std))
plt.plot(y_test_pred, np.exp(y_test_std), ls='', marker='o')

# %% [markdown]
# ## 2.2 Regularizing Layers: Dropout and Batch Normalization
#
# [back to top](#top)
#
# There are dozens of different layer types for accomplishing different tasks (and more are being generated by researchers all the time). While we're on the topic of general model performance, there are two layer types we'll want to introduce here: **_dropout_** and **_batch normalization_** or just batchnorm. What we'll see with both of these types is that while they don't contain any neurons, they're useful to think of as layers, because they are an extra processing step between neural layers.

# %% [markdown]
# ### 2.2.1 Dropout
#
# [back to top](#top)
#
# Dropout is the Neural Network response to the wide success of ensemble learning. In a dropout layer, random neurons are dropped in each batch of training, i.e. their weighted updates are not sent to the next neural layer. Just as with random forests, the end result is that the neural network can be thought of as many _independent models_ that _vote_ on the final output.
#
# Put another way, when a network does not contain dropout layers, and has a capacity that exceeds that which would be suited for the true, underlying complexity level of the data, it can begin to fit to noise. This ability to fit to noise is based on very specific relationships between neurons, which fire uniquely given the particular training example. Adding dropout _breaks_ these specific neural connections, and so the neural network as a whole is forced to find weights that apply generally, as there is no guarantee they will be _turned on_ when their specific training example they would usually overfit for comes around again.
#
# <p align=center>
# <img src="https://i.imgur.com/a86utxY.gif"></img>
# </p>
# <small> Network with 50% dropout </small>
#
# A last thing to note, is that after adding dropout, we will typically need to add additional layers to our network to maintain the overall capacity of the network.

# %%
keras.Sequential([
    # ...
    layers.Dropout(rate=0.3), # apply 30% dropout to the next layer
    layers.Dense(16),
    # ...
])

# %% [markdown]
# When adding dropout to a model we will usually want to increase the depth:

# %%
# Dropout model

model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[X_train_std.shape[1]]),
    layers.Dropout(0.3),
    layers.Dense(512*2, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])

model.compile(
    optimizer='adam',
    loss='mse',
)

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

print(model.summary())

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=256,
    epochs=1000,
    verbose=1,
    callbacks=[early_stopping],
)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               7168
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,057,793
# Trainable params: 1,057,793
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# 15/15 [==============================] - 2s 60ms/step - loss: 0.6070 - val_loss: 0.1379
# Epoch 2/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.1620 - val_loss: 0.0958
# Epoch 3/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.1024 - val_loss: 0.0950
# Epoch 4/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0751 - val_loss: 0.0852
# Epoch 5/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0559 - val_loss: 0.0496
# Epoch 6/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0439 - val_loss: 0.0666
# Epoch 7/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0408 - val_loss: 0.0488
# Epoch 8/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0384 - val_loss: 0.0563
# Epoch 9/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0350 - val_loss: 0.0712
# Epoch 10/1000
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0328 - val_loss: 0.0628
# Epoch 11/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0307 - val_loss: 0.0629
# Epoch 12/1000
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0295 - val_loss: 0.0553
# Epoch 13/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0281 - val_loss: 0.0529
# Epoch 14/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0268 - val_loss: 0.0498
# Epoch 15/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0291 - val_loss: 0.0747
# Epoch 16/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0291 - val_loss: 0.1067
# Epoch 17/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0271 - val_loss: 0.0702
# Epoch 18/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0246 - val_loss: 0.0712
# Epoch 19/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0238 - val_loss: 0.0536
# Epoch 20/1000
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0241 - val_loss: 0.0708
# Epoch 21/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0223 - val_loss: 0.0752
# Epoch 22/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0226 - val_loss: 0.0672
# Epoch 23/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0227 - val_loss: 0.0737
# Epoch 24/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0207 - val_loss: 0.0756
# Epoch 25/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0200 - val_loss: 0.0830

# %% [markdown]
# ### 2.2.2 Batch Normalization
#
# [back to top](#top)
#
# Batch normalization ([batchnorm](https://arxiv.org/abs/1502.03167)) accomplishes a task very similar to sklearn's `StandardScaler`, and in fact, it can be added to the front of a neural network in place of sklearn's `StandardScaler` to scale and center the input data. But batchnorm is also used between layers, why would we want to rescale the output from one layer before feeding into the next? For the same reason we would want to scale and center our data in the first place: it levels the playing field for the following layer to find the important relationships. The optimizer algorithm, SGD, will shift weights in proportion to how large the activation is out of each neuron, and so large differences can lead to spurious behavior.
#
# In practice, batchnorm is often implemented to make the overall training time faster, rather than to improve the final loss (although in some cases it does do this as well). It is good to envoke batchnorm in particular, if you are dealing with neural networks that take a long time to train.
#
# Batchnorm can be added between layers, as well as between a layer and its activation function.

# %%
# BatchNorm model

model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[X_train_std.shape[1]]),
    layers.BatchNormalization(),
    layers.Dense(512*2, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])

model.compile(
    optimizer='adam',
    loss='mse',
)

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

print(model.summary())

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=256,
    epochs=1000,
    verbose=1,
    callbacks=[early_stopping],
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 512)               7168
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,063,937
# Trainable params: 1,060,865
# Non-trainable params: 3,072
# _________________________________________________________________
# None
# Epoch 1/1000
# 15/15 [==============================] - 2s 62ms/step - loss: 3.8759 - val_loss: 2.7732
# Epoch 2/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.5598 - val_loss: 2.0998
# Epoch 3/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.2254 - val_loss: 1.7244
# Epoch 4/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.1540 - val_loss: 1.4695
# Epoch 5/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0869 - val_loss: 1.0595
# Epoch 6/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0535 - val_loss: 0.7462
# Epoch 7/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0875 - val_loss: 0.5454
# Epoch 8/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0400 - val_loss: 0.5062
# Epoch 9/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0304 - val_loss: 0.3614
# Epoch 10/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0474 - val_loss: 0.2405
# Epoch 11/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0365 - val_loss: 0.1911
# Epoch 12/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0330 - val_loss: 0.1340
# Epoch 13/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0402 - val_loss: 0.1210
# Epoch 14/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0432 - val_loss: 0.1124
# Epoch 15/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0581 - val_loss: 0.0706
# Epoch 16/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0559 - val_loss: 0.0592
# Epoch 17/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0441 - val_loss: 0.0663
# Epoch 18/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0452 - val_loss: 0.0769
# Epoch 19/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0342 - val_loss: 0.0604
# Epoch 20/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0371 - val_loss: 0.0524
# Epoch 21/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0367 - val_loss: 0.0608
# Epoch 22/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0346 - val_loss: 0.0461
# Epoch 23/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0319 - val_loss: 0.0574
# Epoch 24/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0490 - val_loss: 0.0657
# Epoch 25/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0472 - val_loss: 0.0533
# Epoch 26/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.1084 - val_loss: 0.0764
# Epoch 27/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0804 - val_loss: 0.0595
# Epoch 28/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0676 - val_loss: 0.0530
# Epoch 29/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0558 - val_loss: 0.0504
# Epoch 30/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0581 - val_loss: 0.0640
# Epoch 31/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0390 - val_loss: 0.0346
# Epoch 32/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0442 - val_loss: 0.0689
# Epoch 33/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0386 - val_loss: 0.0467
# Epoch 34/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0316 - val_loss: 0.0378
# Epoch 35/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0239 - val_loss: 0.0639
# Epoch 36/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0407 - val_loss: 0.0351
# Epoch 37/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0249 - val_loss: 0.0326
# Epoch 38/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0230 - val_loss: 0.0320
# Epoch 39/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0236 - val_loss: 0.0457
# Epoch 40/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0263 - val_loss: 0.0435
# Epoch 41/1000
# 15/15 [==============================] - 1s 62ms/step - loss: 0.0243 - val_loss: 0.0451
# Epoch 42/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0212 - val_loss: 0.0350
# Epoch 43/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0217 - val_loss: 0.0384
# Epoch 44/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0278 - val_loss: 0.0367
# Epoch 45/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0326 - val_loss: 0.0508
# Epoch 46/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0335 - val_loss: 0.0475
# Epoch 47/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0283 - val_loss: 0.0521
# Epoch 48/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0276 - val_loss: 0.0341
# Epoch 49/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0280 - val_loss: 0.0447
# Epoch 50/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0242 - val_loss: 0.0347
# Epoch 51/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0219 - val_loss: 0.0404
# Epoch 52/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0208 - val_loss: 0.0353
# Epoch 53/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0163 - val_loss: 0.0362
# Epoch 54/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0183 - val_loss: 0.0556
# Epoch 55/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0296 - val_loss: 0.0476
# Epoch 56/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0289 - val_loss: 0.0491
# Epoch 57/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0256 - val_loss: 0.0325

# %%
# Show the learning curves
history_df = pd.DataFrame(history.history)
fig, ax = plt.subplots(1,1)
history_df.plot(ax=ax)
ax.set_ylim(0,.2)
# Out:
# (0.0, 0.2)

# %%
y_test_pred = np.exp(model.predict(X_test_std))
plt.plot(y_test_pred, np.exp(y_test_std), ls='', marker='o')

# %% [markdown]
# Model with BatchNorm and Dropout:

# %%
from tensorflow import keras
from tensorflow.keras import layers

# Dropout and BatchNorm Model
model = keras.Sequential([
    layers.Dense(512, input_shape=[X_train_std.shape[1]]),
    layers.BatchNormalization(),
    layers.Activation('relu'), # separate activation
    layers.Dropout(0.3),
    layers.Dense(1024, activation='relu'), # built-in activation
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1),
])

# %%
print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 512)               7168
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 1,065,985
# Trainable params: 1,061,889
# Non-trainable params: 4,096
# _________________________________________________________________
# None

# %% [markdown]
# ### 2.2.3 Exercise: Try Batch Normalization and Dropout
#
# Create 3 models and train for 100 epochs with early stopping:
#
# 1. compile and train the model previously defined above
# 2. recreate the architecture but remove the batchnorm  layers
# 3. recreate the architecture but remove the dropout layers and one hidden, dense layer
#
# Compare the number of epochs required to converge, and the overall loss

# %%
# Dropout and BatchNorm Model
model = keras.Sequential([                      
    ### YOUR CODE HERE ###

])

model.compile(
    optimizer='adam',
    loss='mae',
)

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=256,
    epochs=100,
    verbose=1,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 16ms/step - loss: 1.7653 - val_loss: 1.3092
# Epoch 2/100
# 15/15 [==============================] - 0s 6ms/step - loss: 1.3614 - val_loss: 0.9521
# Epoch 3/100
# 15/15 [==============================] - 0s 7ms/step - loss: 1.0655 - val_loss: 0.6253
# Epoch 4/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.8148 - val_loss: 0.3236
# Epoch 5/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6566 - val_loss: 0.2231
# Epoch 6/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5569 - val_loss: 0.1752
# Epoch 7/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5185 - val_loss: 0.1731
# Epoch 8/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4466 - val_loss: 0.1596
# Epoch 9/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4092 - val_loss: 0.1712
# Epoch 10/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3836 - val_loss: 0.1516
# Epoch 11/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3530 - val_loss: 0.1603
# Epoch 12/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3323 - val_loss: 0.1423
# Epoch 13/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3423 - val_loss: 0.1385
# Epoch 14/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3116 - val_loss: 0.1289
# Epoch 15/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3055 - val_loss: 0.1269
# Epoch 16/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2849 - val_loss: 0.1067
# Epoch 17/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2813 - val_loss: 0.1116
# Epoch 18/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2737 - val_loss: 0.1163
# Epoch 19/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2520 - val_loss: 0.1149
# Epoch 20/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2454 - val_loss: 0.1366
# Epoch 21/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2406 - val_loss: 0.1094
# Epoch 22/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2334 - val_loss: 0.1069
# Epoch 23/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2283 - val_loss: 0.1109
# Epoch 24/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2116 - val_loss: 0.1092
# Epoch 25/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2048 - val_loss: 0.1024
# Epoch 26/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1885 - val_loss: 0.1004
# Epoch 27/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1979 - val_loss: 0.1115
# Epoch 28/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1863 - val_loss: 0.1077
# Epoch 29/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1713 - val_loss: 0.1106
# Epoch 30/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1756 - val_loss: 0.1057
# Epoch 31/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1598 - val_loss: 0.1120
# Epoch 32/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1706 - val_loss: 0.1153
# Epoch 33/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1553 - val_loss: 0.1175
# Epoch 34/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1628 - val_loss: 0.1051
# Epoch 35/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1538 - val_loss: 0.0985
# Epoch 36/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1472 - val_loss: 0.1005
# Epoch 37/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1447 - val_loss: 0.0950
# Epoch 38/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1439 - val_loss: 0.1088
# Epoch 39/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1530 - val_loss: 0.1176
# Epoch 40/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1400 - val_loss: 0.1240
# Epoch 41/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1438 - val_loss: 0.0981
# Epoch 42/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1410 - val_loss: 0.0963
# Epoch 43/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1420 - val_loss: 0.0972
# Epoch 44/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1468 - val_loss: 0.1168
# Epoch 45/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1419 - val_loss: 0.0949
# Epoch 46/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1401 - val_loss: 0.0940
# Epoch 47/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1394 - val_loss: 0.0970
# Epoch 48/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1368 - val_loss: 0.1291
# Epoch 49/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1445 - val_loss: 0.1008
# Epoch 50/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1467 - val_loss: 0.1030
# Epoch 51/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1404 - val_loss: 0.1066
# Epoch 52/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1420 - val_loss: 0.0946
# Epoch 53/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1370 - val_loss: 0.0946
# Epoch 54/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1367 - val_loss: 0.1009
# Epoch 55/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1403 - val_loss: 0.1037
# Epoch 56/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1377 - val_loss: 0.1040
# Epoch 57/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1377 - val_loss: 0.0935
# Epoch 58/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1420 - val_loss: 0.0921
# Epoch 59/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1333 - val_loss: 0.0990
# Epoch 60/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1305 - val_loss: 0.1067
# Epoch 61/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1362 - val_loss: 0.1123
# Epoch 62/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1344 - val_loss: 0.0942
# Epoch 63/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1267 - val_loss: 0.0981
# Epoch 64/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1247 - val_loss: 0.0904
# Epoch 65/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1307 - val_loss: 0.0979
# Epoch 66/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1321 - val_loss: 0.0976
# Epoch 67/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1325 - val_loss: 0.1214
# Epoch 68/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1340 - val_loss: 0.1112
# Epoch 69/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1290 - val_loss: 0.1022
# Epoch 70/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1330 - val_loss: 0.1014
# Epoch 71/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1274 - val_loss: 0.0989
# Epoch 72/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1179 - val_loss: 0.0913
# Epoch 73/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1157 - val_loss: 0.0970
# Epoch 74/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1280 - val_loss: 0.0909
# Epoch 75/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1203 - val_loss: 0.0940
# Epoch 76/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1293 - val_loss: 0.0934
# Epoch 77/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1300 - val_loss: 0.0975
# Epoch 78/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1257 - val_loss: 0.0915
# Epoch 79/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1265 - val_loss: 0.0975
# Epoch 80/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1192 - val_loss: 0.0906
# Epoch 81/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1214 - val_loss: 0.0902
# Epoch 82/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1209 - val_loss: 0.0994
# Epoch 83/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1200 - val_loss: 0.0971
# Epoch 84/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1238 - val_loss: 0.0942

# %% [markdown]
# ## 2.3 Binary Classification with Neural Networks
#
# When dealing with classification tasks, everything we've covered up till now with regression still applies. The main difference is the format of the last layer's outputs and the choice of loss function.

# %% [markdown]
# ### 2.3.1 Accuracy and Cross Entropy
#
# Formerly, we've encountered accuracy in classification tasks. It is the ratio of correct predictions over total predictions: `accuracy = number_corect / total` (and when classes were heavily imballanced we used a weighted accuracy).
#
# The problem with using accuracy as a loss function, is that it does not change smoothly (there are jumps in the numerator since it is just a count in correct predictions), which the SGD algorithm requires in order to work properly. We need another metric.
#
# <p align=center>
# <img src="https://i.imgur.com/DwVV9bR.png"></img>
#
# <small> the further a model is from predicting the correct class, the higher the loss. </small>
#
# Instead we use **_cross-entropy_**, we won't go into detail here, other than that it is a distance measure between two probabilities. What two probabilities are we measuring? We want the probability for predicting the correct class to be 1 (100%). cross-entropy will measure the distance the current probability of the model is from 1. The main takeaway here is that we will want to use cross-entropy for classification tasks.
#
# We set cross-entropy as our loss when we compile the model. In this case we have two classes so we use `binary_crossentropy`
#
# ```
# model.compile(
#     # optimizer...
#     loss='binary_crossentropy',
#     metrics=['binary_accuracy'],
# )
# ```

# %% [markdown]
# ### 2.3.2 0 or 1: The Sigmoid Function
#
# Finally, we need to introduce a special activation function that will map our last layer outputs from 0 to 1, to feed into our loss function. The traditional function we use for this is the **_sigmoid function_**.
#
# <p align=center>
# <img src="https://i.imgur.com/FYbRvJo.png"></img>
#
# <small>The sigmoid function maps values on the interval [0, 1]</small>
#
# To get the final class prediction, we need a threshold probability, typically 0.5 where we will round up to the class label. Keras will set to 0.5 by default.
#
# We set the sigmoid activation function in the last layer:
#
# ```
# model = keras.Sequential([
#     # ... previous layers ...
#     layers.Dense(1, activation='sigmoid'),
# ])
# ```

# %% [markdown]
# ### 2.3.3 Classification Example

# %%
wine = pd.read_csv("https://raw.githubusercontent.com/wesleybeckner/"\
      "ds_for_engineers/main/data/wine_quality/winequalityN.csv")

# create X and y
X = wine.copy()
y = X.pop('type')

# split into train/test
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train)

# the numerical values pipe
num_proc = make_pipeline(SimpleImputer(strategy='median'), StandardScaler())

# the categorical values pipe
cat_proc = make_pipeline(
    SimpleImputer(strategy='constant', fill_value='missing'),
    OneHotEncoder(handle_unknown='ignore'))

# parallelize the two pipes
preprocessor = make_column_transformer((num_proc,
                                make_column_selector(dtype_include=np.number)),
                                       (cat_proc,
                                make_column_selector(dtype_include=object)))

X_train_std = preprocessor.fit_transform(X_train) # fit_transform on train
X_test_std = preprocessor.transform(X_test) # transform test
X_val_std = preprocessor.transform(X_val)

y_train_std = y_train.map({'white': 0, 'red': 1}) # convert to int
y_val_std = y_val.map({'white': 0, 'red': 1}) # convert to int
y_test_std = y_test.map({'white': 0, 'red': 1}) # convert to int

preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f2b2ffa04d0>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f2b2ffa0850>)])

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[X_train_std.shape[1]]),
    layers.Dense(4, activation='relu'),    
    layers.Dense(1, activation='sigmoid'),
])

print(model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 4)                 52
# _________________________________________________________________
# dense_18 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 77
# Trainable params: 77
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
tf.keras.utils.plot_model(model, 
                          show_layer_names=True, 
                          # show_dtype=True, 
                          show_shapes=True)

# %% [markdown]
# We set cross-entropy as our loss when we compile the model. In this case we have two classes so we use `binary_crossentropy`
#
# > Introducing `metrics`: we can track other forms of performance during training with the `metrics` parameter in `model.compile`. We will look at the results when we finish training.

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'], # new metrics flag here
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=512,
    epochs=1000,
    callbacks=[early_stopping],
    verbose=1, 
)
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 1s 22ms/step - loss: 0.6196 - binary_accuracy: 0.7447 - val_loss: 0.6099 - val_binary_accuracy: 0.7635
# Epoch 2/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6035 - binary_accuracy: 0.7638 - val_loss: 0.5936 - val_binary_accuracy: 0.7734
# Epoch 3/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5872 - binary_accuracy: 0.7772 - val_loss: 0.5768 - val_binary_accuracy: 0.7841
# Epoch 4/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5702 - binary_accuracy: 0.7857 - val_loss: 0.5597 - val_binary_accuracy: 0.7890
# Epoch 5/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5530 - binary_accuracy: 0.7915 - val_loss: 0.5422 - val_binary_accuracy: 0.7980
# Epoch 6/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5357 - binary_accuracy: 0.7999 - val_loss: 0.5241 - val_binary_accuracy: 0.8087
# Epoch 7/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5181 - binary_accuracy: 0.8060 - val_loss: 0.5059 - val_binary_accuracy: 0.8161
# Epoch 8/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5002 - binary_accuracy: 0.8142 - val_loss: 0.4874 - val_binary_accuracy: 0.8251
# Epoch 9/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4822 - binary_accuracy: 0.8202 - val_loss: 0.4689 - val_binary_accuracy: 0.8350
# Epoch 10/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4642 - binary_accuracy: 0.8306 - val_loss: 0.4502 - val_binary_accuracy: 0.8481
# Epoch 11/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4459 - binary_accuracy: 0.8415 - val_loss: 0.4318 - val_binary_accuracy: 0.8596
# Epoch 12/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4279 - binary_accuracy: 0.8525 - val_loss: 0.4132 - val_binary_accuracy: 0.8703
# Epoch 13/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4095 - binary_accuracy: 0.8678 - val_loss: 0.3945 - val_binary_accuracy: 0.8842
# Epoch 14/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3914 - binary_accuracy: 0.8826 - val_loss: 0.3758 - val_binary_accuracy: 0.9023
# Epoch 15/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3726 - binary_accuracy: 0.9070 - val_loss: 0.3564 - val_binary_accuracy: 0.9236
# Epoch 16/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3531 - binary_accuracy: 0.9261 - val_loss: 0.3365 - val_binary_accuracy: 0.9409
# Epoch 17/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3334 - binary_accuracy: 0.9409 - val_loss: 0.3169 - val_binary_accuracy: 0.9507
# Epoch 18/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3138 - binary_accuracy: 0.9510 - val_loss: 0.2975 - val_binary_accuracy: 0.9606
# Epoch 19/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2949 - binary_accuracy: 0.9570 - val_loss: 0.2790 - val_binary_accuracy: 0.9672
# Epoch 20/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2770 - binary_accuracy: 0.9595 - val_loss: 0.2617 - val_binary_accuracy: 0.9704
# Epoch 21/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2600 - binary_accuracy: 0.9636 - val_loss: 0.2455 - val_binary_accuracy: 0.9745
# Epoch 22/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2441 - binary_accuracy: 0.9680 - val_loss: 0.2302 - val_binary_accuracy: 0.9778
# Epoch 23/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2293 - binary_accuracy: 0.9704 - val_loss: 0.2157 - val_binary_accuracy: 0.9787
# Epoch 24/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2153 - binary_accuracy: 0.9724 - val_loss: 0.2021 - val_binary_accuracy: 0.9803
# Epoch 25/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2023 - binary_accuracy: 0.9762 - val_loss: 0.1897 - val_binary_accuracy: 0.9819
# Epoch 26/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1902 - binary_accuracy: 0.9787 - val_loss: 0.1784 - val_binary_accuracy: 0.9828
# Epoch 27/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1792 - binary_accuracy: 0.9803 - val_loss: 0.1678 - val_binary_accuracy: 0.9836
# Epoch 28/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1688 - binary_accuracy: 0.9825 - val_loss: 0.1581 - val_binary_accuracy: 0.9844
# Epoch 29/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1592 - binary_accuracy: 0.9844 - val_loss: 0.1492 - val_binary_accuracy: 0.9852
# Epoch 30/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1505 - binary_accuracy: 0.9841 - val_loss: 0.1411 - val_binary_accuracy: 0.9836
# Epoch 31/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1424 - binary_accuracy: 0.9852 - val_loss: 0.1336 - val_binary_accuracy: 0.9860
# Epoch 32/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1351 - binary_accuracy: 0.9858 - val_loss: 0.1268 - val_binary_accuracy: 0.9869
# Epoch 33/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1282 - binary_accuracy: 0.9860 - val_loss: 0.1206 - val_binary_accuracy: 0.9877
# Epoch 34/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1220 - binary_accuracy: 0.9869 - val_loss: 0.1149 - val_binary_accuracy: 0.9910
# Epoch 35/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1163 - binary_accuracy: 0.9874 - val_loss: 0.1097 - val_binary_accuracy: 0.9918
# Epoch 36/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1110 - binary_accuracy: 0.9877 - val_loss: 0.1049 - val_binary_accuracy: 0.9918
# Epoch 37/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1061 - binary_accuracy: 0.9877 - val_loss: 0.1005 - val_binary_accuracy: 0.9918
# Epoch 38/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1017 - binary_accuracy: 0.9880 - val_loss: 0.0964 - val_binary_accuracy: 0.9910
# Epoch 39/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0975 - binary_accuracy: 0.9880 - val_loss: 0.0926 - val_binary_accuracy: 0.9910
# Epoch 40/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0936 - binary_accuracy: 0.9880 - val_loss: 0.0891 - val_binary_accuracy: 0.9910
# Epoch 41/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0900 - binary_accuracy: 0.9880 - val_loss: 0.0858 - val_binary_accuracy: 0.9910
# Epoch 42/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0866 - binary_accuracy: 0.9877 - val_loss: 0.0828 - val_binary_accuracy: 0.9910
# Epoch 43/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0835 - binary_accuracy: 0.9877 - val_loss: 0.0799 - val_binary_accuracy: 0.9910
# Epoch 44/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0806 - binary_accuracy: 0.9885 - val_loss: 0.0773 - val_binary_accuracy: 0.9918
# Epoch 45/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0779 - binary_accuracy: 0.9893 - val_loss: 0.0749 - val_binary_accuracy: 0.9918
# Epoch 46/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0754 - binary_accuracy: 0.9893 - val_loss: 0.0726 - val_binary_accuracy: 0.9918
# Epoch 47/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0731 - binary_accuracy: 0.9893 - val_loss: 0.0705 - val_binary_accuracy: 0.9918
# Epoch 48/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0709 - binary_accuracy: 0.9891 - val_loss: 0.0685 - val_binary_accuracy: 0.9918
# Epoch 49/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0689 - binary_accuracy: 0.9893 - val_loss: 0.0666 - val_binary_accuracy: 0.9918
# Epoch 50/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0669 - binary_accuracy: 0.9899 - val_loss: 0.0649 - val_binary_accuracy: 0.9934
# Epoch 51/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0651 - binary_accuracy: 0.9899 - val_loss: 0.0633 - val_binary_accuracy: 0.9934
# Epoch 52/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0634 - binary_accuracy: 0.9899 - val_loss: 0.0618 - val_binary_accuracy: 0.9934
# Epoch 53/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0619 - binary_accuracy: 0.9904 - val_loss: 0.0604 - val_binary_accuracy: 0.9934
# Epoch 54/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0604 - binary_accuracy: 0.9901 - val_loss: 0.0592 - val_binary_accuracy: 0.9934
# Epoch 55/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0591 - binary_accuracy: 0.9904 - val_loss: 0.0580 - val_binary_accuracy: 0.9934
# Epoch 56/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0578 - binary_accuracy: 0.9904 - val_loss: 0.0569 - val_binary_accuracy: 0.9926
# Epoch 57/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0565 - binary_accuracy: 0.9904 - val_loss: 0.0559 - val_binary_accuracy: 0.9926
# Epoch 58/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0554 - binary_accuracy: 0.9904 - val_loss: 0.0549 - val_binary_accuracy: 0.9926
# Epoch 59/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0543 - binary_accuracy: 0.9904 - val_loss: 0.0540 - val_binary_accuracy: 0.9918
# Epoch 60/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0533 - binary_accuracy: 0.9904 - val_loss: 0.0531 - val_binary_accuracy: 0.9918
# Epoch 61/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0523 - binary_accuracy: 0.9904 - val_loss: 0.0523 - val_binary_accuracy: 0.9918
# Epoch 62/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0513 - binary_accuracy: 0.9904 - val_loss: 0.0514 - val_binary_accuracy: 0.9918
# Epoch 63/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0504 - binary_accuracy: 0.9907 - val_loss: 0.0507 - val_binary_accuracy: 0.9918
# Epoch 64/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0495 - binary_accuracy: 0.9907 - val_loss: 0.0500 - val_binary_accuracy: 0.9918
# Epoch 65/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0487 - binary_accuracy: 0.9912 - val_loss: 0.0493 - val_binary_accuracy: 0.9918
# Epoch 66/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0479 - binary_accuracy: 0.9912 - val_loss: 0.0486 - val_binary_accuracy: 0.9918
# Epoch 67/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0471 - binary_accuracy: 0.9912 - val_loss: 0.0480 - val_binary_accuracy: 0.9918
# Epoch 68/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0464 - binary_accuracy: 0.9912 - val_loss: 0.0475 - val_binary_accuracy: 0.9918
# Epoch 69/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0456 - binary_accuracy: 0.9915 - val_loss: 0.0469 - val_binary_accuracy: 0.9918
# Epoch 70/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0450 - binary_accuracy: 0.9918 - val_loss: 0.0464 - val_binary_accuracy: 0.9918
# Epoch 71/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0443 - binary_accuracy: 0.9918 - val_loss: 0.0459 - val_binary_accuracy: 0.9918
# Epoch 72/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0437 - binary_accuracy: 0.9921 - val_loss: 0.0454 - val_binary_accuracy: 0.9918
# Epoch 73/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0430 - binary_accuracy: 0.9921 - val_loss: 0.0449 - val_binary_accuracy: 0.9918
# Epoch 74/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0424 - binary_accuracy: 0.9923 - val_loss: 0.0444 - val_binary_accuracy: 0.9918
# Epoch 75/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0418 - binary_accuracy: 0.9921 - val_loss: 0.0439 - val_binary_accuracy: 0.9918
# Epoch 76/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0413 - binary_accuracy: 0.9921 - val_loss: 0.0435 - val_binary_accuracy: 0.9918
# Epoch 77/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0407 - binary_accuracy: 0.9921 - val_loss: 0.0433 - val_binary_accuracy: 0.9918
# Epoch 78/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0402 - binary_accuracy: 0.9921 - val_loss: 0.0430 - val_binary_accuracy: 0.9918
# Epoch 79/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0397 - binary_accuracy: 0.9921 - val_loss: 0.0426 - val_binary_accuracy: 0.9918
# Epoch 80/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0392 - binary_accuracy: 0.9921 - val_loss: 0.0423 - val_binary_accuracy: 0.9918
# Epoch 81/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0387 - binary_accuracy: 0.9926 - val_loss: 0.0420 - val_binary_accuracy: 0.9918
# Epoch 82/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0383 - binary_accuracy: 0.9932 - val_loss: 0.0417 - val_binary_accuracy: 0.9918
# Epoch 83/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0378 - binary_accuracy: 0.9932 - val_loss: 0.0414 - val_binary_accuracy: 0.9918
# Epoch 84/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0374 - binary_accuracy: 0.9932 - val_loss: 0.0412 - val_binary_accuracy: 0.9918
# Epoch 85/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0370 - binary_accuracy: 0.9932 - val_loss: 0.0409 - val_binary_accuracy: 0.9918
# Epoch 86/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0366 - binary_accuracy: 0.9932 - val_loss: 0.0407 - val_binary_accuracy: 0.9918
# Epoch 87/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0363 - binary_accuracy: 0.9937 - val_loss: 0.0405 - val_binary_accuracy: 0.9918
# Epoch 88/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0359 - binary_accuracy: 0.9940 - val_loss: 0.0403 - val_binary_accuracy: 0.9918
# Epoch 89/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0355 - binary_accuracy: 0.9940 - val_loss: 0.0401 - val_binary_accuracy: 0.9918
# Epoch 90/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0352 - binary_accuracy: 0.9940 - val_loss: 0.0399 - val_binary_accuracy: 0.9918
# Epoch 91/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0349 - binary_accuracy: 0.9940 - val_loss: 0.0398 - val_binary_accuracy: 0.9918
# Epoch 92/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0346 - binary_accuracy: 0.9940 - val_loss: 0.0396 - val_binary_accuracy: 0.9918
# Epoch 93/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0343 - binary_accuracy: 0.9940 - val_loss: 0.0394 - val_binary_accuracy: 0.9918
# Epoch 94/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0340 - binary_accuracy: 0.9940 - val_loss: 0.0393 - val_binary_accuracy: 0.9918
# Epoch 95/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0337 - binary_accuracy: 0.9943 - val_loss: 0.0391 - val_binary_accuracy: 0.9918
# Epoch 96/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9943 - val_loss: 0.0390 - val_binary_accuracy: 0.9918
# Epoch 97/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0332 - binary_accuracy: 0.9945 - val_loss: 0.0388 - val_binary_accuracy: 0.9918
# Epoch 98/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0329 - binary_accuracy: 0.9945 - val_loss: 0.0387 - val_binary_accuracy: 0.9918
# Epoch 99/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0327 - binary_accuracy: 0.9945 - val_loss: 0.0386 - val_binary_accuracy: 0.9918
# Epoch 100/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0324 - binary_accuracy: 0.9948 - val_loss: 0.0385 - val_binary_accuracy: 0.9918
# Epoch 101/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0322 - binary_accuracy: 0.9948 - val_loss: 0.0384 - val_binary_accuracy: 0.9918
# Epoch 102/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0320 - binary_accuracy: 0.9948 - val_loss: 0.0383 - val_binary_accuracy: 0.9918
# Epoch 103/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0318 - binary_accuracy: 0.9948 - val_loss: 0.0382 - val_binary_accuracy: 0.9918
# Epoch 104/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0316 - binary_accuracy: 0.9948 - val_loss: 0.0381 - val_binary_accuracy: 0.9918
# Epoch 105/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0314 - binary_accuracy: 0.9951 - val_loss: 0.0380 - val_binary_accuracy: 0.9918
# Epoch 106/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0312 - binary_accuracy: 0.9951 - val_loss: 0.0379 - val_binary_accuracy: 0.9918
# Epoch 107/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0310 - binary_accuracy: 0.9951 - val_loss: 0.0378 - val_binary_accuracy: 0.9918
# Epoch 108/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0308 - binary_accuracy: 0.9951 - val_loss: 0.0377 - val_binary_accuracy: 0.9918
# Epoch 109/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0306 - binary_accuracy: 0.9951 - val_loss: 0.0376 - val_binary_accuracy: 0.9918
# Epoch 110/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0304 - binary_accuracy: 0.9951 - val_loss: 0.0375 - val_binary_accuracy: 0.9918
# Epoch 111/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0302 - binary_accuracy: 0.9951 - val_loss: 0.0374 - val_binary_accuracy: 0.9918
# Epoch 112/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0300 - binary_accuracy: 0.9951 - val_loss: 0.0373 - val_binary_accuracy: 0.9918
# Epoch 113/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0298 - binary_accuracy: 0.9951 - val_loss: 0.0372 - val_binary_accuracy: 0.9918
# Epoch 114/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0297 - binary_accuracy: 0.9951 - val_loss: 0.0371 - val_binary_accuracy: 0.9918

# %%
history_df = pd.DataFrame(history.history)

history_df.loc[:, ['loss', 'val_loss']].plot()
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot()

print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(), 
              history_df['val_binary_accuracy'].max()))
# Out:
# Best Validation Loss: 0.0371
# Best Validation Accuracy: 0.9934

# %%
# predict test set
pred_probability = model.predict(X_test_std)

# convert to bool
predictions = pred_probability > 0.5

# precision / recall / f1-score 
print(classification_report(y_test_std,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1234
#            1       0.98      0.98      0.98       391
#
#     accuracy                           0.99      1625
#    macro avg       0.99      0.99      0.99      1625
# weighted avg       0.99      0.99      0.99      1625

# %%
plt.figure(figsize=(10,6))
sns.heatmap(confusion_matrix(y_test_std,predictions),annot=True)

# %% [markdown]
# ## 2.3.4 Multi-Class Classification
#
# [back to top](#top)
#
# It is good practice, and often necessary to one-hot encode the target values for a multi-class problem. We will need to do that with our wine data here.

# %% [markdown]
# #### 2.3.4.1 Exercise: Multi-Class Classification
#
# 1) Define Model
#
# Define a model with both batch normalization and dropout layers.
#
# 2) Add Optimizer, Loss, and Metric
#
# 3) Train and Evaluate

# %%
from keras.utils import np_utils

# %%
wine = pd.read_csv("https://raw.githubusercontent.com/wesleybeckner/"\
      "ds_for_engineers/main/data/wine_quality/winequalityN.csv")

# create X and y
X = wine.copy()
y = X.pop('quality')

# preprocess y for quality and/or type
encoder = LabelEncoder()
encoder.fit(y)
encoded_y = encoder.transform(y)
y = np_utils.to_categorical(encoded_y)

# split into train/test
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train)

# the numerical values pipe
num_proc = make_pipeline(SimpleImputer(strategy='median'), StandardScaler())

# the categorical values pipe
cat_proc = make_pipeline(
    SimpleImputer(strategy='constant', fill_value='missing'),
    OneHotEncoder(handle_unknown='ignore'))

# parallelize the two pipes
preprocessor = make_column_transformer((num_proc,
                                make_column_selector(dtype_include=np.number)),
                                       (cat_proc,
                                make_column_selector(dtype_include=object)))

X_train_std = preprocessor.fit_transform(X_train) # fit_transform on train
X_test_std = preprocessor.transform(X_test) # transform test
X_val_std = preprocessor.transform(X_val)

y_train_std = y_train
y_val_std = y_val
y_test_std = y_test

preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f2b41af1710>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f2ace32c950>)])

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
  ### YOUR MODEL HERE ###
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=512,
    epochs=1000,
    callbacks=[early_stopping],
    verbose=1, # hide the output because we have so many epochs
)
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 1s 37ms/step - loss: 2.2256 - accuracy: 0.3276 - val_loss: 1.7893 - val_accuracy: 0.5287
# Epoch 2/1000
# 8/8 [==============================] - 0s 12ms/step - loss: 1.8694 - accuracy: 0.4264 - val_loss: 1.6499 - val_accuracy: 0.5386
# Epoch 3/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 1.7013 - accuracy: 0.4614 - val_loss: 1.5457 - val_accuracy: 0.5164
# Epoch 4/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.6154 - accuracy: 0.4620 - val_loss: 1.4295 - val_accuracy: 0.5025
# Epoch 5/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.5207 - accuracy: 0.5011 - val_loss: 1.3658 - val_accuracy: 0.4811
# Epoch 6/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.4501 - accuracy: 0.5025 - val_loss: 1.3375 - val_accuracy: 0.4762
# Epoch 7/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.3697 - accuracy: 0.5265 - val_loss: 1.2940 - val_accuracy: 0.4704
# Epoch 8/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.3400 - accuracy: 0.5216 - val_loss: 1.2521 - val_accuracy: 0.4696
# Epoch 9/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.2662 - accuracy: 0.5304 - val_loss: 1.2257 - val_accuracy: 0.4762
# Epoch 10/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 1.2336 - accuracy: 0.5380 - val_loss: 1.2070 - val_accuracy: 0.4795
# Epoch 11/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1775 - accuracy: 0.5512 - val_loss: 1.1872 - val_accuracy: 0.4778
# Epoch 12/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 1.1750 - accuracy: 0.5534 - val_loss: 1.1868 - val_accuracy: 0.4663
# Epoch 13/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1643 - accuracy: 0.5473 - val_loss: 1.1574 - val_accuracy: 0.4729
# Epoch 14/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1273 - accuracy: 0.5468 - val_loss: 1.1444 - val_accuracy: 0.5140
# Epoch 15/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1102 - accuracy: 0.5553 - val_loss: 1.1414 - val_accuracy: 0.4819
# Epoch 16/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0807 - accuracy: 0.5635 - val_loss: 1.1221 - val_accuracy: 0.5172
# Epoch 17/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0841 - accuracy: 0.5457 - val_loss: 1.1256 - val_accuracy: 0.5041
# Epoch 18/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0365 - accuracy: 0.5687 - val_loss: 1.1287 - val_accuracy: 0.5115
# Epoch 19/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 1.0496 - accuracy: 0.5788 - val_loss: 1.1311 - val_accuracy: 0.5181
# Epoch 20/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0129 - accuracy: 0.5857 - val_loss: 1.1116 - val_accuracy: 0.5213
# Epoch 21/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0234 - accuracy: 0.5627 - val_loss: 1.1109 - val_accuracy: 0.5279
# Epoch 22/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0163 - accuracy: 0.5824 - val_loss: 1.1123 - val_accuracy: 0.5287
# Epoch 23/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0072 - accuracy: 0.5791 - val_loss: 1.1022 - val_accuracy: 0.5427
# Epoch 24/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0039 - accuracy: 0.5816 - val_loss: 1.0914 - val_accuracy: 0.5320
# Epoch 25/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 1.0092 - accuracy: 0.5769 - val_loss: 1.0935 - val_accuracy: 0.5255
# Epoch 26/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9788 - accuracy: 0.5928 - val_loss: 1.0825 - val_accuracy: 0.5378
# Epoch 27/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9824 - accuracy: 0.5870 - val_loss: 1.0750 - val_accuracy: 0.5599
# Epoch 28/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9697 - accuracy: 0.5903 - val_loss: 1.0845 - val_accuracy: 0.5468
# Epoch 29/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9719 - accuracy: 0.5900 - val_loss: 1.0768 - val_accuracy: 0.5460
# Epoch 30/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9670 - accuracy: 0.5944 - val_loss: 1.0731 - val_accuracy: 0.5402
# Epoch 31/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.9682 - accuracy: 0.5914 - val_loss: 1.0707 - val_accuracy: 0.5443
# Epoch 32/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9465 - accuracy: 0.6043 - val_loss: 1.0691 - val_accuracy: 0.5476
# Epoch 33/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.9319 - accuracy: 0.6086 - val_loss: 1.0588 - val_accuracy: 0.5657
# Epoch 34/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9449 - accuracy: 0.5958 - val_loss: 1.0693 - val_accuracy: 0.5534
# Epoch 35/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9415 - accuracy: 0.6018 - val_loss: 1.0763 - val_accuracy: 0.5411
# Epoch 36/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9373 - accuracy: 0.6054 - val_loss: 1.0732 - val_accuracy: 0.5558
# Epoch 37/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9118 - accuracy: 0.6136 - val_loss: 1.0576 - val_accuracy: 0.5575
# Epoch 38/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9135 - accuracy: 0.6086 - val_loss: 1.0528 - val_accuracy: 0.5558
# Epoch 39/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8991 - accuracy: 0.6174 - val_loss: 1.0484 - val_accuracy: 0.5534
# Epoch 40/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9150 - accuracy: 0.6149 - val_loss: 1.0554 - val_accuracy: 0.5657
# Epoch 41/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9073 - accuracy: 0.6204 - val_loss: 1.0406 - val_accuracy: 0.5624
# Epoch 42/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9087 - accuracy: 0.6215 - val_loss: 1.0432 - val_accuracy: 0.5493
# Epoch 43/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9004 - accuracy: 0.6125 - val_loss: 1.0392 - val_accuracy: 0.5583
# Epoch 44/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9180 - accuracy: 0.6070 - val_loss: 1.0414 - val_accuracy: 0.5608
# Epoch 45/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8955 - accuracy: 0.6169 - val_loss: 1.0373 - val_accuracy: 0.5616
# Epoch 46/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8874 - accuracy: 0.6262 - val_loss: 1.0347 - val_accuracy: 0.5616
# Epoch 47/1000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.8879 - accuracy: 0.6223 - val_loss: 1.0451 - val_accuracy: 0.5583
# Epoch 48/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8708 - accuracy: 0.6344 - val_loss: 1.0375 - val_accuracy: 0.5665
# Epoch 49/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8812 - accuracy: 0.6185 - val_loss: 1.0445 - val_accuracy: 0.5525
# Epoch 50/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8771 - accuracy: 0.6300 - val_loss: 1.0524 - val_accuracy: 0.5517
# Epoch 51/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.8567 - accuracy: 0.6363 - val_loss: 1.0581 - val_accuracy: 0.5476
# Epoch 52/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8609 - accuracy: 0.6270 - val_loss: 1.0401 - val_accuracy: 0.5624
# Epoch 53/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8629 - accuracy: 0.6319 - val_loss: 1.0385 - val_accuracy: 0.5673
# Epoch 54/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8500 - accuracy: 0.6292 - val_loss: 1.0472 - val_accuracy: 0.5583
# Epoch 55/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8647 - accuracy: 0.6336 - val_loss: 1.0310 - val_accuracy: 0.5567
# Epoch 56/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8373 - accuracy: 0.6385 - val_loss: 1.0435 - val_accuracy: 0.5550
# Epoch 57/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.8596 - accuracy: 0.6336 - val_loss: 1.0454 - val_accuracy: 0.5624
# Epoch 58/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8447 - accuracy: 0.6440 - val_loss: 1.0483 - val_accuracy: 0.5558
# Epoch 59/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8347 - accuracy: 0.6445 - val_loss: 1.0415 - val_accuracy: 0.5640
# Epoch 60/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.8275 - accuracy: 0.6434 - val_loss: 1.0405 - val_accuracy: 0.5567
# Epoch 61/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8387 - accuracy: 0.6390 - val_loss: 1.0628 - val_accuracy: 0.5534
# Epoch 62/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8294 - accuracy: 0.6409 - val_loss: 1.0629 - val_accuracy: 0.5608
# Epoch 63/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8195 - accuracy: 0.6492 - val_loss: 1.0490 - val_accuracy: 0.5542
# Epoch 64/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8271 - accuracy: 0.6489 - val_loss: 1.0382 - val_accuracy: 0.5722
# Epoch 65/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8065 - accuracy: 0.6639 - val_loss: 1.0669 - val_accuracy: 0.5468

# %%
history_df = pd.DataFrame(history.history)

history_df.loc[:, ['loss', 'val_loss']].plot()
history_df.loc[:, ['accuracy', 'val_accuracy']].plot()

print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(), 
              history_df['val_accuracy'].max()))
# Out:
# Best Validation Loss: 1.0310
# Best Validation Accuracy: 0.5722

# %%
# predict test set
pred_probability = model.predict(X_test_std)

# convert to bool
predictions = pred_probability > 0.5

# precision / recall / f1-score 
print(classification_report(y_test_std,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.11      0.18         9
#            1       0.00      0.00      0.00        54
#            2       0.62      0.63      0.63       516
#            3       0.56      0.62      0.59       717
#            4       0.62      0.16      0.26       286
#            5       0.00      0.00      0.00        41
#            6       0.00      0.00      0.00         2
#
#    micro avg       0.59      0.51      0.54      1625
#    macro avg       0.33      0.22      0.24      1625
# weighted avg       0.56      0.51      0.51      1625
#  samples avg       0.51      0.51      0.51      1625
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # References
#
# [Difference between a batch and an epoch](https://machinelearningmastery.com/difference-between-a-batch-and-an-epoch/)
#
# [Cross Entropy](https://machinelearningmastery.com/cross-entropy-for-machine-learning/)
